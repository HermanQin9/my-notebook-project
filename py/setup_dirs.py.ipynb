# %%
pip install scikit-learn pandas numpy matminer pymatgen torch stable-baselines3 gym networkx psutil pynvml tqdm matplotlib joblib
# Out:
# Requirement already satisfied: scikit-learn in d:\anaconda\lib\site-packages (1.3.2)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (1.5.3)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (1.23.5)
# Requirement already satisfied: matminer in c:\users\48103\appdata\roaming\python\python38\site-packages (0.9.0)
# Requirement already satisfied: pymatgen in c:\users\48103\appdata\roaming\python\python38\site-packages (2023.8.10)
# Requirement already satisfied: torch in d:\anaconda\lib\site-packages (2.4.1)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.4.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting gym
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ------------------------------------- 721.7/721.7 kB 14.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx in d:\anaconda\lib\site-packages (2.5)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (5.7.2)
# Requirement already satisfied: pynvml in d:\anaconda\lib\site-packages (11.5.3)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (4.67.1)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (3.7.5)
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (1.4.2)
# Requirement already satisfied: scipy>=1.5.0 in d:\anaconda\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from matminer) (2.31.0)
# Requirement already satisfied: pymongo in c:\users\48103\appdata\roaming\python\python38\site-packages (from matminer) (4.10.1)
# Requirement already satisfied: future in d:\anaconda\lib\site-packages (from matminer) (0.18.2)
# Requirement already satisfied: sympy in d:\anaconda\lib\site-packages (from matminer) (1.6.2)
# Requirement already satisfied: monty in d:\anaconda\lib\site-packages (from matminer) (2023.9.25)
# Requirement already satisfied: mp-api>=0.27.3 in c:\users\48103\appdata\roaming\python\python38\site-packages (from pymatgen) (0.35.1)
# Requirement already satisfied: palettable>=3.1.1 in d:\anaconda\lib\site-packages (from pymatgen) (3.3.3)
# Requirement already satisfied: plotly>=4.5.0 in c:\users\48103\appdata\roaming\python\python38\site-packages (from pymatgen) (5.24.1)
# Requirement already satisfied: pybtex in c:\users\48103\appdata\roaming\python\python38\site-packages (from pymatgen) (0.24.0)
# Requirement already satisfied: pydantic<2.0.0 in d:\anaconda\lib\site-packages (from pymatgen) (1.10.21)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: spglib>=2.0.2 in d:\anaconda\lib\site-packages (from pymatgen) (2.4.0)
# Requirement already satisfied: tabulate in d:\anaconda\lib\site-packages (from pymatgen) (0.9.0)
# Requirement already satisfied: uncertainties>=3.1.4 in d:\anaconda\lib\site-packages (from pymatgen) (3.2.2)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from torch) (3.0.12)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\anaconda\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from torch) (3.0.3)
# Requirement already satisfied: fsspec in d:\anaconda\lib\site-packages (from torch) (2024.12.0)
# Collecting gymnasium<1.1.0,>=0.29.1 (from stable-baselines3)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: cloudpickle in d:\anaconda\lib\site-packages (from stable-baselines3) (1.6.0)
# Collecting gym-notices>=0.0.4 (from gym)
#   Downloading gym_notices-0.0.8-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: importlib-metadata>=4.8.0 in d:\anaconda\lib\site-packages (from gym) (6.8.0)
# Requirement already satisfied: decorator>=4.3.0 in d:\anaconda\lib\site-packages (from networkx) (4.4.2)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\anaconda\lib\site-packages (from matplotlib) (6.4.5)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.1.0,>=0.29.1->stable-baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda\lib\site-packages (from importlib-metadata>=4.8.0->gym) (3.20.2)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from mp-api>=0.27.3->pymatgen) (75.3.2)
# Requirement already satisfied: msgpack in d:\anaconda\lib\site-packages (from mp-api>=0.27.3->pymatgen) (1.0.0)
# Requirement already satisfied: emmet-core>=0.54.0 in c:\users\48103\appdata\roaming\python\python38\site-packages (from mp-api>=0.27.3->pymatgen) (0.68.0)
# Requirement already satisfied: tenacity>=6.2.0 in d:\anaconda\lib\site-packages (from plotly>=4.5.0->pymatgen) (9.0.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests->matminer) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->matminer) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->matminer) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->matminer) (2025.4.26)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in d:\anaconda\lib\site-packages (from ruamel.yaml>=0.17.0->pymatgen) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: PyYAML>=3.01 in d:\anaconda\lib\site-packages (from pybtex->pymatgen) (5.3.1)
# Requirement already satisfied: latexcodec>=1.0.4 in d:\anaconda\lib\site-packages (from pybtex->pymatgen) (3.0.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\anaconda\lib\site-packages (from pymongo->matminer) (2.6.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda\lib\site-packages (from sympy->matminer) (1.1.0)
# Downloading stable_baselines3-2.4.1-py3-none-any.whl (183 kB)
# Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    --------------------------------------- 958.1/958.1 kB 22.5 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827633 sha256=8c4b41ea6fcc507eb2bf584e5c36dd1cd6e67782a011df513bc53b40dbca898b
#   Stored in directory: c:\users\48103\appdata\local\pip\cache\wheels\17\79\65\7afedc162d858b02708a3b8f7a6dd5b1000dcd5b0f894f7cc1
# Successfully built gym
# Installing collected packages: gym-notices, farama-notifications, ruamel.yaml, gymnasium, gym, stable-baselines3
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel.yaml 0.18.11
#     Uninstalling ruamel.yaml-0.18.11:
#       Successfully uninstalled ruamel.yaml-0.18.11
# Successfully installed farama-notifications-0.0.4 gym-0.26.2 gym-notices-0.0.8 gymnasium-1.0.0 ruamel.yaml-0.15.87 stable-baselines3-2.4.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)

# %%
# 初始化项目结构 — 在 Jupyter Notebook 中运行这一整段

# 1. 创建目录
import os

dirs = ["data/raw", "data/processed", "models", "logs", "dash_app/data"]
for d in dirs:
    os.makedirs(d, exist_ok=True)
    print(f"Created folder: {d}")

# 2. 创建基础脚本文件
files = {
    "pipeline.py": r"""\
# pipeline.py — baseline pipeline 模块
import os, time
import numpy as np
import pandas as pd
import joblib
import psutil
from mp_api.client import MPRester
from matminer.featurizers.composition import ElementProperty
from matminer.featurizers.structure import DensityFeatures, GlobalSymmetryFeatures
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error

def run_pipeline(config, df):
    # TODO: 在此实现 N1–N6 步骤
    mae_val = 0.0
    total_cost = 0.0
    return mae_val, total_cost, None
""",
    "env.py": r"""\
# env.py — PPO 环境封装
import gym
import numpy as np
import networkx as nx
from pipeline import run_pipeline

class PipelineEnv(gym.Env):
    def __init__(self, df_train):
        super().__init__()
        self.df = df_train
        self.budget = 100.0
        self.config = {}

    def reset(self):
        self.config = {}  # TODO: 填充默认 config
        self.budget = 100.0
        mae, cost, _ = run_pipeline(self.config, self.df)
        return None  # TODO: 返回 state
        
    def step(self, action):
        # TODO: 应用 action 修改 config 并运行 pipeline
        return None, 0.0, False, {}

    def graph_consistent(self, config):
        # TODO: 实现 DAG 检查逻辑
        return True
""",
    "train_ppo.py": r"""\
# train_ppo.py — 训练入口脚本
from stable_baselines3 import PPO
from env import PipelineEnv
import pandas as pd

if __name__ == "__main__":
    df_train = pd.read_csv("data/processed/non_fe.csv")  # TODO: 修改为实际路径
    env = PipelineEnv(df_train)
    model = PPO("MlpPolicy", env, verbose=1, clip_range=0.2, target_kl=0.01)
    model.learn(total_timesteps=10000)
    model.save("models/ppo_pipeline.zip")
    print("PPO model trained and saved.")
"""
}

# 写入文件
for fname, content in files.items():
    with open(fname, "w", encoding="utf-8") as f:
        f.write(content)
    print(f"Created file: {fname}")
# Out:
# Created folder: data/raw
# Created folder: data/processed
# Created folder: models
# Created folder: logs
# Created folder: dash_app/data
# Created file: pipeline.py
# Created file: env.py
# Created file: train_ppo.py

# %%
# env.py
import gym
from gym import spaces
import numpy as np
import networkx as nx
from pipeline import run_pipeline  # stub 版

class PipelineEnv(gym.Env):
    def __init__(self, df_train):
        super().__init__()
        self.df = df_train
        # 假设 7 个节点，每个最多 3 种方法
        self.n_nodes = 7
        self.n_methods = 3
        # action：node（7），method（3），两个 hyperparams 连续
        self.action_space = spaces.Dict({
            "node": spaces.Discrete(self.n_nodes),
            "method": spaces.Discrete(self.n_methods),
            "hp": spaces.Box(low=0.0, high=1.0, shape=(2,), dtype=np.float32)
        })
        # state：one-hot 方法选择 + mae + cost + 剩余预算
        self.observation_space = spaces.Box(low=0, high=1, shape=(self.n_nodes*self.n_methods + 3,), dtype=np.float32)
        self.budget = 100.0
        self.config = {}

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.budget = 100.0
        self.config = {i: 0 for i in range(self.n_nodes)}  # 默认方法 0
        mae, cost, _ = run_pipeline(self.config, self.df)
        return self._build_state(mae, cost), {}

    def step(self, action):
        prev_config = self.config.copy()
        node = action["node"]
        method = action["method"]
        hp = action["hp"]
        self.config[node] = method
        if not self.graph_consistent():
            self.config = prev_config
            return self._build_state(0,0), -1.0, False, {}
        mae, cost, _ = run_pipeline(self.config, self.df)
        self.budget -= cost
        reward = -mae - 0.01 * cost  # example
        done = self.budget <= 0
        return self._build_state(mae, cost), reward, done, {}

    def _build_state(self, mae, cost):
        onehot = np.zeros(self.n_nodes*self.n_methods, dtype=np.float32)
        for n, m in self.config.items():
            onehot[n*self.n_methods + m] = 1.0
        return np.concatenate([onehot, [mae, cost, self.budget]])

    def graph_consistent(self):
        # 简单检查无环境断链；demo 中直接 return True
        return True

# %%
from env import PipelineEnv
import pandas as pd
df = pd.DataFrame()  # stub
env = PipelineEnv(df)
from stable_baselines3.common.env_checker import check_env
check_env(env)
from stable_baselines3.common.env_checker import check_env
env = PipelineEnv(pd.DataFrame())
check_env(env)
# Out:
# [autoreload of env failed: Traceback (most recent call last):
#   File "D:\Anaconda\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "D:\Anaconda\lib\site-packages\IPython\extensions\autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "D:\Anaconda\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "D:\Anaconda\lib\site-packages\IPython\extensions\autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "D:\Anaconda\lib\site-packages\IPython\extensions\autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "D:\Anaconda\lib\site-packages\IPython\extensions\autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: reset() requires a code object with 0 free vars, not 1
# ]
# D:\Anaconda\lib\site-packages\stable_baselines3\common\env_checker.py:461: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# D:\Anaconda\lib\site-packages\stable_baselines3\common\env_checker.py:461: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(

# %%
pip install stable-baselines3==1.7.0 gym==0.21
# Out:
# Collecting stable-baselines3==1.7.0
#   Downloading stable_baselines3-1.7.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [3 lines of output]
#   D:\Anaconda\lib\site-packages\setuptools\_distutils\dist.py:261: UserWarning: Unknown distribution option: 'tests_require'
#     warnings.warn(msg)
#   error in gym setup command: 'extras_require' must be a dictionary whose values are strings or lists of strings containing valid project/version requirement specifiers.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
